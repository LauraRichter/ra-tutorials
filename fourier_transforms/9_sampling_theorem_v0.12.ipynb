# %% [markdown]
# #9. The Sampling Theorem#

# %% [markdown]
# This notebook takes a look at the Nyquist-Shannon Sampling Theorem, from a Fourier perspective.A simple statement of the Sampling theorem is: <br/>The sampling frequency should be at least twice the highest frequency contained in the signal.The sample frequency which meets this requirement is called the Nyquist frequency, and its reciprocal is the Nyquist rate, which is the rate the signal should be sampled at to avoid aliasing.So if the highest frequency in our signal is $\nu_{max}$, our Nyquist frequency is $2\times\nu_{max}$, and our Nyquist rate, the rate we need to sample the signal at, is $\Delta t = 1/ (2 \nu_{max})$. Lets explore this theorem using our Fourier skills.First import the necessary modules:

# %%
import numpy as npimport matplotlib.pylab as plt

# %% [markdown]
# Make our convenience functions using the fourier transform provided by numpy:

# %%
def ft(y):    """Returns the fourier transform of y"""    return np.fft.fftshift(np.fft.fft(np.fft.fftshift(y)))def ift(y):    """Returns the inverse fourier transform of y"""    return np.fft.fftshift(np.fft.ifft(np.fft.fftshift(y)))def ftfreqs(N,dt):    """Returns the Fourier frequencies"""    return np.fft.fftshift(np.fft.fftfreq(N,dt))

# %% [markdown]
# Lets define some of the frequently used functions again, so we can play with them:

# %%
# gaussian functiondef gaussian(t,sigma):    return (1./(np.sqrt(2.*np.pi)*sigma))*np.exp(-t**2.0/(2.*sigma**2.0))

# %%
# comb functiondef comb(t,t_space,A):    output = np.zeros(len(t))    mod_array = np.array([round(i,2)%t_space for i in t])    output[mod_array==0] = A    return output

# %%
# top-hat functiondef tophat(t,width,A):    output = np.zeros(len(t))    output[abs(t)<width/2.0] = A    return output

# %% [markdown]
# Lets create a function that is a Gaussian, but will a frequency cutoff at a particular frequency. We can do this by multiplying our function by a tophat function in the Fourier domain.Start off with setting up our x-axis values:(Disclaimer - the time range set here is actually a cheat. We want to set it to an integral number of the shah/comb period we use later, just to avoid FFT folding effects. So we chose this number to be an integral multiple of the comb period we use later.)

# %%
delta_t = 1.0t = np.arange(-1040,1040,delta_t)              # set x-axis valuefreqs = ftfreqs(len(t),delta_t)                # get our Fourier transform frequency values

# %% [markdown]
# What parameters shall we use? <br/>Lets start with a Gaussian of sigma 50.0. The Fourier transform of a Gaussian with standard deviation of $\sigma_0$ is $1/(2*\pi*\sigma_0)$. So the Fourier transform of our Gaussian will have a standard deviation of $1/(2*\pi*5)$.Lets cut the frequency of at, say, 1.5 times the Fourier domain standard deviation:

# %%
sig_0 = 50.0h = gaussian(t,sig_0)                          # create gaussian function  H = ft(h)                                      # Fourier transformsig_f = 1/(2.*np.pi*sig_0)print 'time domain standard deviation:      ', sig_0print 'frequency domain standard deviation: ', sig_ff_max = 1.5*sig_ffilter = tophat(freqs,2*f_max,1.0)     # create a top hat from -f_max to f_max, total width 2*f_max H_flimit = H*filter                    # multiply our FT by the top hat to cut off frequencies > f_maxh_flimit = ift(H_flimit)
# Out:
# time domain standard deviation:       50.0frequency domain standard deviation:  0.00318309886184

# %% [markdown]
# Now lets plot our Gaussian and our chopped-off Gaussian, to check:

# %%
fig, ax = plt.subplots(1,2,figsize=[13,4])     # create plotax[0].plot(t,h,'g')ax[0].plot(t,h_flimit,'b')ax[0].set_xlabel('Time')ax[0].set_ylabel('h(t) (real)')ax[1].plot(freqs,H.real,'g')ax[1].plot(freqs,H_flimit.real,'b')ax[1].plot(freqs,filter,'k:')ax[1].set_xlabel('Frequency')ax[1].set_ylabel('H(f) (real)')ax[0].set_xlim(-250.,250.)ax[1].set_xlim(-0.04,0.04)
# Out:
# (-0.04, 0.04)

# %% [markdown]
# So we will use our frequency-limited function h_flimit hereafter.The sampling theorem says we should sample at a frequency of double our max frequency to fully reconstruct our signal. So lets do that first.

# %%
sample_freq = 2*f_maxsample_period = 1/sample_freqprint 'Sample frequency: ', sample_freqprint 'Sample period:    ', sample_period
# Out:
# Sample frequency:  0.00954929658551Sample period:     104.71975512

# %% [markdown]
# We will use a shah / comb function to sample our time-domain function atthe sample frequency we want. We do this by multiplying our time-domain signal by the comb to select a subset of points ta regular spacings (sample it!)

# %%
# first round our sample period to integer values - this is just because of how we have defined our comb functionsample_period = floor(sample_period)g = comb(t,sample_period,1.0)                            # create function f(t)G = ft(g)                                      # Fourier transformfig, ax = plt.subplots(1,2,figsize=[13,4])     # create plotax[0].plot(t,g,'o-')ax[0].set_xlabel('Time')ax[0].set_ylabel('g(t) (real)')ax[1].plot(freqs,G.real)ax[1].set_xlabel('Frequency')ax[1].set_ylabel('G(f) (real)')ax[0].set_xlim(-500.,500.)ax[1].set_xlim(-0.4,0.4)
# Out:
# (-0.4, 0.4)

# %% [markdown]
# Now multiply our frequency limited signal h_limit by our sampling function comb, to sample our signal at the desired sampling period, then Fourier transform it:

# %%
y = h_flimit*g# then Fourier transform:Y = ft(y)

# %% [markdown]
# Now plot our sampled time-domain function (left) and its Fourier transform (right). We will also plot the Fourier transform of our original unsampled time-domain signal in red on both plots.

# %%
fig, ax = plt.subplots(1,2,figsize=[13,4])     # create plotax[0].plot(t,h_flimit,'r')ax[0].plot(t,y,'b-o')ax[0].set_xlabel('Time')ax[0].set_ylabel('y(t) (real)')ax[1].plot(freqs,Y.real)ax[1].plot(freqs,H_flimit.real/100.,'r')ax[1].set_xlabel('Frequency')ax[1].set_ylabel('Y(f) (real)')ax[0].set_xlim(-500.,500.)ax[1].set_xlim(-0.07,0.07)
# Out:
# (-0.07, 0.07)

# %% [markdown]
# You can see on the left how multiplication by the comb has sampled our original (red) function. On the right you can see how this sampling has led to the function being repeated across the Fourier-domain function (because of the Convolution theorem!)On the left we see that our functions just avoid overlapping - that is because we samped at the Nyquist rate! Now lets see what happens if we sample at a lower rate than the nyquist rate. Let's re-do the exercise above using a sample period of 150 (the Nyquist sample rate above is 104.7).
